# %%
from IPython.display import Image
Image(filename='./images/1-0-0-0_opening.jpg')

# %% [markdown]
# # Learning Plan

# %% [markdown]
# ### Lesson 1-1 : Introduction to CV
# - Learn where computer vision techniques are used in industry.
# - Prepare for the course ahead with a detailed topic overview.
# - Start programming your own applications
#
# ### Lesson 1-2 : Image Representation and Analysis
# - See how images are represented numerically.
# - Implement image processing techniques like color and geometric transforms.
# - Program your own convolutional kernel for object edge-detection.
#
# ### Lesson 1-3 : Convolutional Neural Network Layers
# - Learn about the layers of a deep convolutional neural network: convolutional, maxpooling, and fully-connected layers.
# - Build an CNN-based image classifier in PyTorch.
# - Learn about layer activation and feature visualization techniques.

# %% [markdown]
# ### Lesson 1-4 : Features and Object Detection
# - Learn why distinguishing features are important in pattern and object recognition tasks.
# - Write code to extract information about an object’s color and shape.
# - Use features to identify areas on a face and to recognize the shape of a car or pedestrian on a road.
#
# ### Lesson 1-5 : Image Segmentation
# - Implement k-means clustering to break an image up into parts.
# - Find the contours and edges of multiple objects in an image.
# - Learn about background subtraction for video.

# %% [markdown]
# # Lesson 1-1 : Introduction to CV
#
# How we can build computers or machines which can see and interpret images

# %% [markdown]
# ## 1-1-1 : What is Computer Vision ?

# %%
from IPython.display import Image
Image(filename='./images/1-1-1-1_what_is_cv.png')

# %% [markdown]
# ### CV vs. CP
#
# #### - Computer Vision = Interpret images
# ![computer vision example](./images/1-1-1-3_cv_example.png)
# #### - Computational Photography = Manipulate images
# ![computational photography example](./images/1-1-1-2_cp_example.png)

# %% [markdown]
# ## 1-1-2 : Why Study Computer Vision ?
#
# ### * Images have become ubiquitous in both production and consumption.
# ### * Applications to manipulate images are becoming core.
# ### * Systems that extract information from images are also becoming core.
#
#     - Surveillance
#     - Building 3D representationsj
#     - Motion capture assisted

# %% [markdown]
# ## 1-1-3 : CV Applications

# %% [markdown]
# ### OCR(Optical Character Recognition)
#
# #### Technology to convert scanned docs to text

# %% [markdown]
# #### Scanners with OCR
# ![OCR license plate reader](./images/1-1-1-4_ocr_license_plate_reader.png)

# %% [markdown]
# #### ATM(Automatic Teller Machine) with Handwritten Digit Recognition

# %%
from IPython.display import HTML
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/FwFduRA_L6Q" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/FwFduRA_L6Q" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ### Face Detection and more
#
# Most digital cameras and smart phones can detect faces ...

# %%
from IPython.display import HTML
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/KUJwidmYdQc" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/KUJwidmYdQc" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# even some can detect blinking and smiling

# %%
from IPython.display import HTML
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/KUJwidmYdQc" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
